# %%
import pandas as pd
import numpy as np

exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}

df1 = pd.DataFrame(exam_data, index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])

print(df1)

print("\n")

print(df1.head(3))

df1 = df1.dropna()

print("\n")

print(df1)

print("\n")

print(df1[['name','score']])

dict1 = {'name':'Suresh', 'score':15.5, 'attempts': 'yes', 'qualify': 'yes'}

new_row = pd.DataFrame(dict1, index = ['k'])
df2 = pd.concat([df1,new_row])

print("\n")

print(df2)

df3 = df2.drop("attempts", axis = 1)

print("\n")

list1 = []

for i in df3.score:
    if i > 10:
        list1.append(1)
    else:
        list1.append(0)
        

df3.insert(3,'success',li)

print(df3)

df3.to_csv('exam_data.csv')
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
#
#
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
#
#
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
#
#
#         name  score
# ...
